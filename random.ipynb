# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Set plot size

# %%
plt.rcParams['figure.figsize'] = (17.0, 10.0)

# %% [markdown]
# ## Read the dataset

# %%
train = pd.read_csv("train.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## Categorize each column as numerical or categorical

# %%
# https://www.questionpro.com/blog/nominal-ordinal-interval-ratio/
numerical_columns = ["LotFrontage","LotArea",]
ordinal_columns = ["LotShape","Utilities"]
nominal_columns = ["MSSubClass","MSZoning","Street","Alley","LandContour"]

# %% [markdown]
# ## Scatter plots

# %%
plt.plot(train["LotArea"], train["SalePrice"], "r.")

# %% [markdown]
# ## Correlation heat map

# %%
sns.heatmap(train[numerical_columns].corr(), annot=True, fmt=".2f")
